# %%
pip install neo4j python-dotenv pandas pyvis

# %%
from neo4j import GraphDatabase

# URI examples: "neo4j://localhost", "neo4j+s://xxx.databases.neo4j.io"
URI = "bolt://localhost:7687"
AUTH = ("neo4j", "password")

with GraphDatabase.driver(URI, auth=AUTH) as driver:
    with driver.session(database="neo4j") as session: # explicit db allows the driver to work more efficiently
        driver.verify_connectivity()
        print("Connection established.")
# Out:
# Connection established.

# %%
# Get the name of all 42 year-olds
records, summary, keys = driver.execute_query(
    "MATCH (p:PLAYER) WHERE p.name = 'LeBron James' RETURN p",
    # auth_=("neo4j", "password"),  run query as someone else instead of creating a new driver
    database_="neo4j", # speciry the database to connect to here
)

# run query as a different user
driver.execute_query(
    "MATCH (p:Person) RETURN p.name",
    impersonated_user_="somebody_else",
    database_="neo4j",
)

driver.execute_query(
    "MATCH (p:Person) RETURN p.name",
    auth_=("somebody_else", "their_password"),
    database_="neo4j",
)

# %%
class Player:
    def __init__(self, name, age):
        self.name = name
        self.age = age

# %%
def formatter(records, summary=None, keys=None):
    # Loop through results and do something with them
    for record in records:
        print(record.data())  # obtain record as dict

    if summary and keys:
        # Summary information
        print("The query `{query}` returned {records_count} records in {time} ms.".format(
            query=summary.query, records_count=len(records),
            time=summary.result_available_after
        ))

# %%
def create(player: Player):
    try:
        records, summary, keys = driver.execute_query(
            """CREATE (player:PLAYER {name: $name, age: $age}) RETURN player""",
            name= player.name,
            age= player.age
            )
        return records, summary, keys
    except Exception as e:
        print(e)
        raise e

records, summary, keys = create(Player(name= "Ezra", age= 23))
formatter(records, summary, keys)
# Out:
# {'player': {'name': 'Ezra', 'age': 23}}
# The query `CREATE (player:PLAYER {name: $name, age: $age}) RETURN player` returned 1 records in 1 ms.
# /var/folders/pq/j682cyjd7cb0xq6g_rj_397w0000gn/T/ipykernel_29955/2350641073.py:3: DeprecationWarning: Using a driver after it has been closed is deprecated. Future versions of the driver will raise an error.
#   records, summary, keys = driver.execute_query(

# %%
# create if player with given properties does not exist
def create_if_no_exist(player: Player):
    try:
        records, summary, keys = driver.execute_query(
            """MERGE (player:PLAYER {name: $name, age: $age}) RETURN player""",
            name= player.name,
            age= player.age
            )
        return records, summary, keys
    except Exception as e:
        print(e)
        raise e

records, summary, keys = create_if_no_exist(Player(name= "Ezra", age= 23)) 
formatter(records, summary, keys)
# Out:
# {'player': {'name': 'Ezra', 'age': 23}}
# The query `MERGE (player:PLAYER {name: $name, age: $age}) RETURN player` returned 1 records in 1 ms.
# /var/folders/pq/j682cyjd7cb0xq6g_rj_397w0000gn/T/ipykernel_29955/1823666447.py:4: DeprecationWarning: Using a driver after it has been closed is deprecated. Future versions of the driver will raise an error.
#   records, summary, keys = driver.execute_query(

# %%
def read():
    try:
        records, summary, keys = driver.execute_query("""
            MATCH (p:PLAYER) RETURN p""")
        return records, summary, keys
    except Exception as e:
        print(e)
        raise e

records, summary, keys = read()
formatter(records, summary, keys)
# Out:
# {'p': {'name': 'Carolynn', 'age': 23}}
# {'p': {'name': 'Ezra', 'age': '25'}}
# {'p': {'name': 'Ezra', 'age': 23}}
# The query `
#             MATCH (p:PLAYER) RETURN p` returned 3 records in 2 ms.
# /var/folders/pq/j682cyjd7cb0xq6g_rj_397w0000gn/T/ipykernel_29955/2625414688.py:3: DeprecationWarning: Using a driver after it has been closed is deprecated. Future versions of the driver will raise an error.
#   records, summary, keys = driver.execute_query("""

# %%
def update(name, player:Player):
    try:
        records, summary, keys = driver.execute_query(f"""
            MATCH (player: PLAYER)
            WHERE player.name = "{name}"
            SET player.name = $name, player.age=$age
            RETURN player
            """,
            parameters_ = player.__dict__
            )
        return records, summary, keys
    except Exception as e:
        print(e)
        raise e

records, summary, keys = update("Ezra",Player(name="Ezra", age="25"))
formatter(records, summary, keys)
# Out:
# {'player': {'name': 'Ezra', 'age': '25'}}
# The query `
#             MATCH (player: PLAYER)
#             WHERE player.name = "Ezra"
#             SET player.name = $name, player.age=$age
#             RETURN player
#             ` returned 1 records in 18 ms.
# /var/folders/pq/j682cyjd7cb0xq6g_rj_397w0000gn/T/ipykernel_29955/2235784898.py:3: DeprecationWarning: Using a driver after it has been closed is deprecated. Future versions of the driver will raise an error.
#   records, summary, keys = driver.execute_query(f"""

# %%
def add_relationship():
    driver.execute_query("""
        MATCH (ezra: PLAYER {name: "Ezra"})
        MATCH (carol: PLAYER {name: "Carolynn"})
        CREATE (ezra)-[:TEAMMATES]->(carol)
    """)
add_relationship()
# Out:
# /var/folders/pq/j682cyjd7cb0xq6g_rj_397w0000gn/T/ipykernel_29955/3319249233.py:2: DeprecationWarning: Using a driver after it has been closed is deprecated. Future versions of the driver will raise an error.
#   driver.execute_query("""

# %%
driver.execute_query("MATCH (n) DETACH DELETE n")
# Out:
# /var/folders/pq/j682cyjd7cb0xq6g_rj_397w0000gn/T/ipykernel_29955/3405002177.py:1: DeprecationWarning: Using a driver after it has been closed is deprecated. Future versions of the driver will raise an error.
#   driver.execute_query("MATCH (n) DETACH DELETE n")
# EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x10f069e10>, keys=[])

# %%
import neo4j

# %%
# transform to pandas dataframe
pandas_df = driver.execute_query("""
                MATCH (p:PLAYER) RETURN p""", 
                result_transformer_=neo4j.Result.to_df
            )
pandas_df.head()
# Out:
# /var/folders/pq/j682cyjd7cb0xq6g_rj_397w0000gn/T/ipykernel_29955/2949146807.py:2: DeprecationWarning: Using a driver after it has been closed is deprecated. Future versions of the driver will raise an error.
#   pandas_df = driver.execute_query("""
#              p
# 0  (name, age)
# 1  (name, age)

# %%
# transform to graph
graph_result = driver.execute_query("""
                MATCH (p:PLAYER) RETURN p""", 
                result_transformer_=neo4j.Result.graph
            )
graph_result
# Out:
# /var/folders/pq/j682cyjd7cb0xq6g_rj_397w0000gn/T/ipykernel_29955/738753035.py:2: DeprecationWarning: Using a driver after it has been closed is deprecated. Future versions of the driver will raise an error.
#   graph_result = driver.execute_query("""

# %%
import pyvis

def visualize_result(query_graph, nodes_text_properties):
    visual_graph = pyvis.network.Network()

    for node in query_graph.nodes:
        node_label = list(node.labels)[0]
        node_text = node[nodes_text_properties[node_label]]
        visual_graph.add_node(node.element_id, node_text, group=node_label)

    for relationship in query_graph.relationships:
        visual_graph.add_edge(
            relationship.start_node.element_id,
            relationship.end_node.element_id,
            title=relationship.type
        )

    visual_graph.show('network.html', notebook=False)

# %%
nodes_text_properties = {  # what property to use as text for each node
            "PLAYER": "name",
        }
visualize_result(graph_result, nodes_text_properties)
# Out:
# network.html

# %% [markdown]
# # Running a managed transaction

# %%
# transaction callback function
def match_player(tx, filter):
    result = tx.run(
        """
            MATCH (p:PLAYER)
            WHERE p.name  STARTS WITH $filter
            RETURN p.name AS name, p.age AS age
            ORDER BY p.name
        """, 
        filter=filter
    )
    return list (result) # always cast the Result obj into a list

# sessions are lightweight so can be created multiple times compared to drivers
with driver.session(database="neo4j") as session:
    players = session.execute_read(match_player, "Car")
    session.close()
formatter(players)
# Out:
# {'name': 'Carolynn', 'age': 23}
# /var/folders/pq/j682cyjd7cb0xq6g_rj_397w0000gn/T/ipykernel_29955/2757852450.py:14: DeprecationWarning: Using a driver after it has been closed is deprecated. Future versions of the driver will raise an error.
#   with driver.session(database="neo4j") as session:

# %%
# configure a transaction behaviour using decorators
from neo4j import unit_of_work
@unit_of_work(timeout=5, metadata={"app_name": "Player tracker"})
def count_player(tx):
    result = tx.run("""
            MATCH (player:PLAYER)
            RETURN COUNT(player) as no_players
        """)
    record = result.single()
    return record["no_players"]

with driver.session(database="neo4j") as session:
    player_n  = session.execute_read(count_player)
player_n
# Out:
# /var/folders/pq/j682cyjd7cb0xq6g_rj_397w0000gn/T/ipykernel_29955/3265026717.py:12: DeprecationWarning: Using a driver after it has been closed is deprecated. Future versions of the driver will raise an error.
#   with driver.session(database="neo4j") as session:
# 3

# %%
with driver.session(
    database="neo4j", 
    # auth=() # switching user at sesion level is cheap than creating new Diver object
    # impersonated_user="somebody" # will be useful if need to alter something so you are given permission
    ) as session:
    with session.begin_transaction() as tx: # create a transaction and run multimple queries within it 
        tx.run("MERGE (player: PLAYER {name: 'Tarus', age:25, status: 'single asf'})")
        result = tx.run("MATCH (n) RETURN n")  
        print(result.data())
        # tx.commit()
# Out:
# [{'n': {'name': 'Carolynn', 'age': 23}}, {'n': {'name': 'Ezra', 'age': '25'}}, {'n': {'name': 'Ezra', 'age': 23}}, {'n': {'name': 'Tarus', 'age': 25, 'status': 'single asf'}}]
# /var/folders/pq/j682cyjd7cb0xq6g_rj_397w0000gn/T/ipykernel_29955/4275692550.py:1: DeprecationWarning: Using a driver after it has been closed is deprecated. Future versions of the driver will raise an error.
#   with driver.session(database="neo4j") as session:

# %% [markdown]
# ### An end to end transaction very good

# %%
import neo4j


URI = "<URI for Neo4j database>"
AUTH = ("<Username>", "<Password>")


def main():
    with neo4j.GraphDatabase.driver(URI, auth=AUTH) as driver:
        customer_id = create_customer(driver)
        other_bank_id = 42
        transfer_to_other_bank(driver, customer_id, other_bank_id, 999)


def create_customer(driver):
    result, _, _ = driver.execute_query("""
        MERGE (c:Customer {id: rand()})
        RETURN c.id AS id
    """, database_ = "neo4j")
    return result[0]["id"]


def transfer_to_other_bank(driver, customer_id, other_bank_id, amount):
    with driver.session(database="neo4j") as session:
        with session.begin_transaction() as tx:
            if not customer_balance_check(tx, customer_id, amount):
                # give up
                return

            other_bank_transfer_api(customer_id, other_bank_id, amount)
            # Now the money has been transferred => can't rollback anymore
            # (cannot rollback external services interactions)

            try:
                decrease_customer_balance(tx, customer_id, amount)
                tx.commit()
            except Exception as e:
                request_inspection(customer_id, other_bank_id, amount, e)
                raise  # roll back


def customer_balance_check(tx, customer_id, amount):
    query = ("""
        MATCH (c:Customer {id: $id})
        RETURN c.balance >= $amount AS sufficient
    """)
    result = tx.run(query, id=customer_id, amount=amount)
    record = result.single(strict=True)
    return record["sufficient"]


def other_bank_transfer_api(customer_id, other_bank_id, amount):
    # make some API call to other bank
    pass


def decrease_customer_balance(tx, customer_id, amount):
    query = ("""
        MATCH (c:Customer {id: $id})
        SET c.balance = c.balance - $amount
    """)
    result = tx.run(query, id=customer_id, amount=amount)
    result.consume()


def request_inspection(customer_id, other_bank_id, amount, e):
    # manual cleanup required; log this or similar
    print("WARNING: transaction rolled back due to exception:", repr(e))
    print("customer_id:", customer_id, "other_bank_id:", other_bank_id,
          "amount:", amount)


if __name__ == "__main__":
    main()

# %%
from neo4j import GraphDatabase, Bookmarks


URI = "<URI for Neo4j database>"
AUTH = ("<Username>", "<Password>")

def main():
    with GraphDatabase.driver(URI, auth=AUTH) as driver:
        driver.verify_connectivity()
        create_some_friends(driver)


def create_some_friends(driver):
    saved_bookmarks = Bookmarks()  # To collect the sessions' bookmarks

    # Create the first person and employment relationship
    with driver.session(database="neo4j") as session_a:
        session_a.execute_write(create_person, "Alice")
        session_a.execute_write(employ, "Alice", "Wayne Enterprises")
        saved_bookmarks += session_a.last_bookmarks()

    # Create the second person and employment relationship
    with driver.session(database="neo4j") as session_b:
        session_b.execute_write(create_person, "Bob")
        session_b.execute_write(employ, "Bob", "LexCorp")
        saved_bookmarks += session_b.last_bookmarks()

    # Create a friendship between the two people created above
    with driver.session(
        database="neo4j", bookmarks=saved_bookmarks
    ) as session_c:
        session_c.execute_write(create_friendship, "Alice", "Bob")
        session_c.execute_read(print_friendships)


# Create a person node
def create_person(tx, name):
    tx.run("MERGE (:Person {name: $name})", name=name)


# Create an employment relationship to a pre-existing company node
# This relies on the person first having been created.
def employ(tx, person_name, company_name):
    tx.run("""
        MATCH (person:Person {name: $person_name})
        MATCH (company:Company {name: $company_name})
        CREATE (person)-[:WORKS_FOR]->(company)
        """, person_name=person_name, company_name=company_name
    )


# Create a friendship between two people
def create_friendship(tx, name_a, name_b):
    tx.run("""
        MATCH (a:Person {name: $name_a})
        MATCH (b:Person {name: $name_b})
        MERGE (a)-[:KNOWS]->(b)
        """, name_a=name_a, name_b=name_b
    )


# Retrieve and display all friendships
def print_friendships(tx):
    result = tx.run("MATCH (a)-[:KNOWS]->(b) RETURN a.name, b.name")
    for record in result:
        print("{} knows {}".format(record["a.name"], record["b.name"]))


if __name__ == "__main__":
    main()

# %% [markdown]
# ### asynchronouse execution

# %%
import asyncio
from neo4j import AsyncGraphDatabase


URI = "<URI for Neo4j database>"
AUTH = ("<Username>", "<Password>")


async def main():
    async with AsyncGraphDatabase.driver(URI, auth=AUTH) as driver:
        records, summary, keys = await driver.execute_query(
            "MATCH (a:Person) RETURN a.name AS name",
            database_="neo4j"
        )
        names = [record["name"] for record in records]
        print(names)


if __name__ == "__main__":
    asyncio.run(main())

# %% [markdown]
# Implicit runs session.run() useful in executions that might timeout

# %%
with driver.session(database="neo4j") as session:
    result = session.run("""
        LOAD CSV FROM 'https://data.neo4j.com/bands/artists.csv' AS line
        CALL {
            WITH line
            MERGE (:Artist {name: line[1], age: toInteger(line[2])})
        } IN TRANSACTIONS OF 2 ROWS
    """)
    print(result.consume().counters)
# Out:
# /var/folders/pq/j682cyjd7cb0xq6g_rj_397w0000gn/T/ipykernel_29955/2363721342.py:1: DeprecationWarning: Using a driver after it has been closed is deprecated. Future versions of the driver will raise an error.
#   with driver.session(database="neo4j") as session:
# Received notification from DBMS server: {severity: WARNING} {code: Neo.ClientNotification.Statement.FeatureDeprecationWarning} {category: DEPRECATION} {title: This feature is deprecated and will be removed in future versions.} {description: CALL subquery without a variable scope clause is now deprecated. Use CALL (line) { ... }} {position: line: 3, column: 9, offset: 82} for query: "\n        LOAD CSV FROM 'https://data.neo4j.com/bands/artists.csv' AS line\n        CALL {\n            WITH line\n            MERGE (:Artist {name: line[1], age: toInteger(line[2])})\n        } IN TRANSACTIONS OF 2 ROWS\n    "
# {'_contains_updates': True, 'labels_added': 4, 'nodes_created': 4, 'properties_set': 8}

# %% [markdown]
# `property keys, so MATCH (n) WHERE n.$param = 'something' is invalid;`
#
# `relationship types, so MATCH (n)-[:$param]→(m) is invalid;`
#
# `labels, so MATCH (n:$param) is invalid.`

# %%
# escape labels when you have to cocnatenate in the query to prevent cypher injection
label = "Person\\u0060n"
# convert \u0060 to literal backtick and then escape backticks
escaped_label = label.replace("\\u0060", "`").replace("`", "``")

driver.execute_query(
    f"MATCH (p:`{escaped_label}` {{name: $name}}) RETURN p.name",
    name="Alice",
    database_="neo4j"
)

# %%
property_key = "name"
label = "Person"

driver.execute_query(
    "CALL apoc.merge.node($labels, $properties)",
    labels=[label], properties={property_key: "Alice"},
    database_="neo4j"
)

# %% [markdown]
# Lazy loading and eager loading

# %%
import neo4j
from time import sleep, time
import tracemalloc



URI = "bolt://localhost:7687"
AUTH = ("neo4j", "password")

# Returns 250 records, each with properties
# - `output` (an expensive computation, to slow down retrieval)
# - `dummyData` (a list of 10000 ints, about 8 KB).
slow_query = '''
UNWIND range(1, 250) AS s
RETURN reduce(s=s, x in range(1,1000000) | s + sin(toFloat(x))+cos(toFloat(x))) AS output,
       range(1, 10000) AS dummyData
'''
# Delay for each processed record
sleep_time = 0.5


def main():
    with neo4j.GraphDatabase.driver(URI, auth=AUTH) as driver:
        driver.verify_connectivity()

        start_time = time()
        log('LAZY LOADING (execute_read)')
        tracemalloc.start()
        lazy_loading(driver)
        log(f'Peak memory usage: {tracemalloc.get_traced_memory()[1]} bytes')
        tracemalloc.stop()
        log('--- %s seconds ---' % (time() - start_time))

        start_time = time()
        log('EAGER LOADING (execute_query)')
        tracemalloc.start()
        eager_loading(driver)
        log(f'Peak memory usage: {tracemalloc.get_traced_memory()[1]} bytes')
        tracemalloc.stop()
        log('--- %s seconds ---' % (time() - start_time))


def lazy_loading(driver):

    def process_records(tx):
        log('Submit query')
        result = tx.run(slow_query)

        for record in result:
            log(f'Processing record {int(record.get("output"))}')
            sleep(sleep_time)  # proxy for some expensive operation

    with driver.session(database='neo4j') as session:
        processed_result = session.execute_read(process_records)


def eager_loading(driver):
    log('Submit query')
    records, _, _ = driver.execute_query(slow_query, database_='neo4j')

    for record in records:
        log(f'Processing record {int(record.get("output"))}')
        sleep(sleep_time)  # proxy for some expensive operation


def log(msg):
    print(f'[{round(time(), 2)}] {msg}')


if __name__ == '__main__':
    main()
# Out:
# [1734946846.32] LAZY LOADING (execute_read)
# [1734946846.33] Submit query
# [1734946846.76] Processing record 0
# [1734946847.32] Processing record 1
# [1734946847.9] Processing record 2
# [1734946848.46] Processing record 3
# [1734946849.01] Processing record 4
# [1734946849.57] Processing record 5
# [1734946850.13] Processing record 6
# [1734946850.7] Processing record 7
# [1734946851.26] Processing record 8
# [1734946851.82] Processing record 9
# [1734946852.38] Processing record 10
# [1734946852.93] Processing record 11
# [1734946853.49] Processing record 12
# [1734946854.05] Processing record 13
# [1734946854.6] Processing record 14
# [1734946855.16] Processing record 15
# [1734946855.72] Processing record 16
# [1734946856.27] Processing record 17
# [1734946856.82] Processing record 18
# [1734946857.37] Processing record 19
# [1734946857.92] Processing record 20
# [1734946858.47] Processing record 21
# [1734946859.02] Processing record 22
# [1734946859.56] Processing record 23
# [1734946860.11] Processing record 24
# [1734946860.66] Processing record 25
# [1734946861.2] Processing record 26
# [1734946861.75] Processing record 27
# [1734946862.3] Processing record 28
# [1734946862.85] Processing record 29
# [1734946863.4] Processing record 30
# [1734946863.95] Processing record 31
# [1734946864.5] Processing record 32
# [1734946865.04] Processing record 33
# [1734946865.59] Processing record 34
# [1734946866.14] Processing record 35
# [1734946866.68] Processing record 36
# [1734946867.23] Processing record 37
# [1734946867.82] Processing record 38
# [1734946868.37] Processing record 39
# [1734946868.93] Processing record 40
# [1734946869.47] Processing record 41
# [1734946870.02] Processing record 42
# [1734946870.57] Processing record 43
# [1734946871.11] Processing record 44
# [1734946871.66] Processing record 45
# [1734946872.21] Processing record 46
# [1734946872.76] Processing record 47
# [1734946873.3] Processing record 48
# [1734946873.85] Processing record 49
# [1734946874.4] Processing record 50
# [1734946874.93] Processing record 51
# [1734946875.48] Processing record 52
# [1734946876.04] Processing record 53
# [1734946876.59] Processing record 54
# [1734946877.13] Processing record 55
# [1734946877.67] Processing record 56
# [1734946878.22] Processing record 57
# [1734946878.77] Processing record 58
# [1734946879.31] Processing record 59
# [1734946879.86] Processing record 60
# [1734946880.41] Processing record 61
# [1734946880.95] Processing record 62
# [1734946881.5] Processing record 63
# [1734946882.05] Processing record 64
# [1734946882.6] Processing record 65
# [1734946883.14] Processing record 66
# [1734946883.69] Processing record 67
# [1734946884.24] Processing record 68
# [1734946884.79] Processing record 69
# [1734946885.33] Processing record 70
# [1734946885.88] Processing record 71
# [1734946886.44] Processing record 72
# [1734946886.98] Processing record 73
# [1734946887.53] Processing record 74
# [1734946888.08] Processing record 75
# [1734946888.62] Processing record 76
# [1734946889.17] Processing record 77
# [1734946889.72] Processing record 78
# [1734946890.26] Processing record 79
# [1734946890.81] Processing record 80
# [1734946891.36] Processing record 81
# [1734946891.91] Processing record 82
# [1734946892.45] Processing record 83
# [1734946893.0] Processing record 84
# [1734946893.55] Processing record 85
# [1734946894.09] Processing record 86
# [1734946894.63] Processing record 87
# [1734946895.18] Processing record 88
# [1734946895.73] Processing record 89
# [1734946896.28] Processing record 90
# [1734946896.82] Processing record 91
# [1734946897.37] Processing record 92
# [1734946897.92] Processing record 93
# [1734946898.47] Processing record 94
# [1734946899.01] Processing record 95
# [1734946899.56] Processing record 96
# [1734946900.11] Processing record 97
# [1734946900.65] Processing record 98
# [1734946901.2] Processing record 99
# [1734946901.75] Processing record 100
# [1734946902.3] Processing record 101
# [1734946902.84] Processing record 102
# [1734946903.39] Processing record 103
# [1734946903.94] Processing record 104
# [1734946904.49] Processing record 105
# [1734946905.03] Processing record 106
# [1734946905.58] Processing record 107
# [1734946906.13] Processing record 108
# [1734946906.68] Processing record 109
# [1734946907.21] Processing record 110
# [1734946907.78] Processing record 111
# [1734946908.32] Processing record 112
# [1734946908.87] Processing record 113
# [1734946909.42] Processing record 114
# [1734946909.97] Processing record 115
# [1734946910.51] Processing record 116
# [1734946911.05] Processing record 117
# [1734946911.61] Processing record 118
# [1734946912.15] Processing record 119
# [1734946912.69] Processing record 120
# [1734946913.24] Processing record 121
# [1734946913.79] Processing record 122
# [1734946914.34] Processing record 123
# [1734946914.88] Processing record 124
# [1734946915.43] Processing record 125
# [1734946915.97] Processing record 126
# [1734946916.52] Processing record 127
# [1734946917.06] Processing record 128
# [1734946917.6] Processing record 129
# [1734946918.16] Processing record 130
# [1734946918.7] Processing record 131
# [1734946919.24] Processing record 132
# [1734946919.79] Processing record 133
# [1734946920.34] Processing record 134
# [1734946920.88] Processing record 135
# [1734946921.43] Processing record 136
# [1734946921.97] Processing record 137
# [1734946922.52] Processing record 138
# [1734946923.09] Processing record 139
# [1734946923.64] Processing record 140
# [1734946924.18] Processing record 141
# [1734946924.73] Processing record 142
# [1734946925.27] Processing record 143
# [1734946925.82] Processing record 144
# [1734946926.37] Processing record 145
# [1734946926.92] Processing record 146
# [1734946927.48] Processing record 147
# [1734946928.03] Processing record 148
# [1734946928.58] Processing record 149
# [1734946929.13] Processing record 150
# [1734946929.68] Processing record 151
# [1734946930.21] Processing record 152
# [1734946930.76] Processing record 153
# [1734946931.31] Processing record 154
# [1734946931.86] Processing record 155
# [1734946932.4] Processing record 156
# [1734946932.94] Processing record 157
# [1734946933.49] Processing record 158
# [1734946934.04] Processing record 159
# [1734946934.59] Processing record 160
# [1734946935.14] Processing record 161
# [1734946935.69] Processing record 162
# [1734946936.23] Processing record 163
# [1734946936.77] Processing record 164
# [1734946937.32] Processing record 165
# [1734946937.87] Processing record 166
# [1734946938.44] Processing record 167
# [1734946939.02] Processing record 168
# [1734946939.56] Processing record 169
# [1734946940.12] Processing record 170
# [1734946940.67] Processing record 171
# [1734946941.21] Processing record 172
# [1734946941.75] Processing record 173
# [1734946942.3] Processing record 174
# [1734946942.85] Processing record 175
# [1734946943.39] Processing record 176
# [1734946943.94] Processing record 177
# [1734946944.49] Processing record 178
# [1734946945.04] Processing record 179
# [1734946945.58] Processing record 180
# [1734946946.13] Processing record 181
# [1734946946.68] Processing record 182
# [1734946947.23] Processing record 183
# [1734946947.77] Processing record 184
# [1734946948.32] Processing record 185
# [1734946948.87] Processing record 186
# [1734946949.41] Processing record 187
# [1734946949.95] Processing record 188
# [1734946950.5] Processing record 189
# [1734946951.05] Processing record 190
# [1734946951.6] Processing record 191
# [1734946952.14] Processing record 192
# [1734946952.69] Processing record 193
# [1734946953.24] Processing record 194
# [1734946953.79] Processing record 195
# [1734946954.33] Processing record 196
# [1734946954.87] Processing record 197
# [1734946955.42] Processing record 198
# [1734946955.97] Processing record 199
# [1734946956.51] Processing record 200
# [1734946957.06] Processing record 201
# [1734946957.61] Processing record 202
# [1734946958.16] Processing record 203
# [1734946958.7] Processing record 204
# [1734946959.25] Processing record 205
# [1734946959.8] Processing record 206
# [1734946960.35] Processing record 207
# [1734946960.89] Processing record 208
# [1734946961.44] Processing record 209
# [1734946961.99] Processing record 210
# [1734946962.54] Processing record 211
# [1734946963.08] Processing record 212
# [1734946963.62] Processing record 213
# [1734946964.18] Processing record 214
# [1734946964.72] Processing record 215
# [1734946965.26] Processing record 216
# [1734946965.81] Processing record 217
# [1734946966.36] Processing record 218
# [1734946966.91] Processing record 219
# [1734946967.45] Processing record 220
# [1734946968.0] Processing record 221
# [1734946968.55] Processing record 222
# [1734946969.09] Processing record 223
# [1734946969.64] Processing record 224
# [1734946970.18] Processing record 225
# [1734946970.73] Processing record 226
# [1734946971.28] Processing record 227
# [1734946971.82] Processing record 228
# [1734946972.37] Processing record 229
# [1734946972.92] Processing record 230
# [1734946973.47] Processing record 231
# [1734946974.01] Processing record 232
# [1734946974.56] Processing record 233
# [1734946975.1] Processing record 234
# [1734946975.65] Processing record 235
# [1734946976.19] Processing record 236
# [1734946976.74] Processing record 237
# [1734946977.29] Processing record 238
# [1734946977.84] Processing record 239
# [1734946978.38] Processing record 240
# [1734946978.92] Processing record 241
# [1734946979.47] Processing record 242
# [1734946980.02] Processing record 243
# [1734946980.56] Processing record 244
# [1734946981.1] Processing record 245
# [1734946981.66] Processing record 246
# [1734946982.21] Processing record 247
# [1734946982.75] Processing record 248
# [1734946983.29] Processing record 249
# [1734946983.8] Peak memory usage: 804365 bytes
# [1734946983.8] --- 137.4867079257965 seconds ---
# [1734946983.8] EAGER LOADING (execute_query)
# [1734946983.8] Submit query
# [1734946996.74] Processing record 0
# [1734946997.25] Processing record 1
# [1734946997.75] Processing record 2
# [1734946998.26] Processing record 3
# [1734946998.76] Processing record 4
# [1734946999.27] Processing record 5
# [1734946999.77] Processing record 6
# [1734947000.28] Processing record 7
# [1734947000.78] Processing record 8
# [1734947001.29] Processing record 9
# [1734947001.79] Processing record 10
# [1734947002.3] Processing record 11
# [1734947002.8] Processing record 12
# [1734947003.31] Processing record 13
# [1734947003.81] Processing record 14
# [1734947004.32] Processing record 15
# [1734947004.82] Processing record 16
# [1734947005.33] Processing record 17
# [1734947005.83] Processing record 18
# [1734947006.34] Processing record 19
# [1734947006.84] Processing record 20
# [1734947007.35] Processing record 21
# [1734947007.85] Processing record 22
# [1734947008.36] Processing record 23
# [1734947008.86] Processing record 24
# [1734947009.37] Processing record 25
# [1734947009.88] Processing record 26
# [1734947010.38] Processing record 27
# [1734947010.89] Processing record 28
# [1734947011.39] Processing record 29
# [1734947011.89] Processing record 30
# [1734947012.4] Processing record 31
# [1734947012.9] Processing record 32
# [1734947013.41] Processing record 33
# [1734947013.91] Processing record 34
# [1734947014.42] Processing record 35
# [1734947014.92] Processing record 36
# [1734947015.42] Processing record 37
# [1734947015.93] Processing record 38
# [1734947016.43] Processing record 39
# [1734947016.94] Processing record 40
# [1734947017.44] Processing record 41
# [1734947017.95] Processing record 42
# [1734947018.46] Processing record 43
# [1734947018.96] Processing record 44
# [1734947019.46] Processing record 45
# [1734947019.97] Processing record 46
# [1734947020.47] Processing record 47
# [1734947020.98] Processing record 48
# [1734947021.48] Processing record 49
# [1734947021.99] Processing record 50
# [1734947022.49] Processing record 51
# [1734947023.0] Processing record 52
# [1734947023.5] Processing record 53
# [1734947024.01] Processing record 54
# [1734947024.51] Processing record 55
# [1734947025.01] Processing record 56
# [1734947025.52] Processing record 57
# [1734947026.02] Processing record 58
# [1734947026.52] Processing record 59
# [1734947027.03] Processing record 60
# [1734947027.54] Processing record 61
# [1734947028.04] Processing record 62
# [1734947028.55] Processing record 63
# [1734947029.05] Processing record 64
# [1734947029.56] Processing record 65
# [1734947030.06] Processing record 66
# [1734947030.57] Processing record 67
# [1734947031.07] Processing record 68
# [1734947031.58] Processing record 69
# [1734947032.08] Processing record 70
# [1734947032.59] Processing record 71
# [1734947033.09] Processing record 72
# [1734947033.6] Processing record 73
# [1734947034.1] Processing record 74
# [1734947034.61] Processing record 75
# [1734947035.11] Processing record 76
# [1734947035.62] Processing record 77
# [1734947036.12] Processing record 78
# [1734947036.63] Processing record 79
# [1734947037.13] Processing record 80
# [1734947037.64] Processing record 81
# [1734947038.15] Processing record 82
# [1734947038.65] Processing record 83
# [1734947039.16] Processing record 84
# [1734947039.66] Processing record 85
# [1734947040.17] Processing record 86
# [1734947040.67] Processing record 87
# [1734947041.18] Processing record 88
# [1734947041.68] Processing record 89
# [1734947042.19] Processing record 90
# [1734947042.69] Processing record 91
# [1734947043.2] Processing record 92
# [1734947043.7] Processing record 93
# [1734947044.21] Processing record 94
# [1734947044.71] Processing record 95
# [1734947045.22] Processing record 96
# [1734947045.72] Processing record 97
# [1734947046.23] Processing record 98
# [1734947046.73] Processing record 99
# [1734947047.24] Processing record 100
# [1734947047.74] Processing record 101
# [1734947048.25] Processing record 102
# [1734947048.76] Processing record 103
# [1734947049.26] Processing record 104
# [1734947049.77] Processing record 105
# [1734947050.27] Processing record 106
# [1734947050.78] Processing record 107
# [1734947051.28] Processing record 108
# [1734947051.79] Processing record 109
# [1734947052.29] Processing record 110
# [1734947052.8] Processing record 111
# [1734947053.3] Processing record 112
# [1734947053.81] Processing record 113
# [1734947054.31] Processing record 114
# [1734947054.82] Processing record 115
# [1734947055.32] Processing record 116
# [1734947055.83] Processing record 117
# [1734947056.33] Processing record 118
# [1734947056.84] Processing record 119
# [1734947057.34] Processing record 120
# [1734947057.85] Processing record 121
# [1734947058.35] Processing record 122
# [1734947058.86] Processing record 123
# [1734947059.36] Processing record 124
# [1734947059.87] Processing record 125
# [1734947060.37] Processing record 126
# [1734947060.88] Processing record 127
# [1734947061.38] Processing record 128
# [1734947061.89] Processing record 129
# [1734947062.39] Processing record 130
# [1734947062.9] Processing record 131
# [1734947063.4] Processing record 132
# [1734947063.91] Processing record 133
# [1734947064.41] Processing record 134
# [1734947064.92] Processing record 135
# [1734947065.42] Processing record 136
# [1734947065.93] Processing record 137
# [1734947066.43] Processing record 138
# [1734947066.94] Processing record 139
# [1734947067.44] Processing record 140
# [1734947067.95] Processing record 141
# [1734947068.46] Processing record 142
# [1734947068.96] Processing record 143
# [1734947069.47] Processing record 144
# [1734947069.97] Processing record 145
# [1734947070.48] Processing record 146
# [1734947070.98] Processing record 147
# [1734947071.49] Processing record 148
# [1734947071.99] Processing record 149
# [1734947072.49] Processing record 150
# [1734947073.0] Processing record 151
# [1734947073.51] Processing record 152
# [1734947074.01] Processing record 153
# [1734947074.52] Processing record 154
# [1734947075.02] Processing record 155
# [1734947075.53] Processing record 156
# [1734947076.03] Processing record 157
# [1734947076.54] Processing record 158
# [1734947077.04] Processing record 159
# [1734947077.55] Processing record 160
# [1734947078.05] Processing record 161
# [1734947078.56] Processing record 162
# [1734947079.06] Processing record 163
# [1734947079.57] Processing record 164
# [1734947080.07] Processing record 165
# [1734947080.58] Processing record 166
# [1734947081.08] Processing record 167
# [1734947081.59] Processing record 168
# [1734947082.09] Processing record 169
# [1734947082.6] Processing record 170
# [1734947083.1] Processing record 171
# [1734947083.61] Processing record 172
# [1734947084.11] Processing record 173
# [1734947084.62] Processing record 174
# [1734947085.12] Processing record 175
# [1734947085.63] Processing record 176
# [1734947086.13] Processing record 177
# [1734947086.64] Processing record 178
# [1734947087.14] Processing record 179
# [1734947087.64] Processing record 180
# [1734947088.15] Processing record 181
# [1734947088.65] Processing record 182
# [1734947089.16] Processing record 183
# [1734947089.66] Processing record 184
# [1734947090.17] Processing record 185
# [1734947090.67] Processing record 186
# [1734947091.18] Processing record 187
# [1734947091.68] Processing record 188
# [1734947092.19] Processing record 189
# [1734947092.69] Processing record 190
# [1734947093.19] Processing record 191
# [1734947093.7] Processing record 192
# [1734947094.2] Processing record 193
# [1734947094.7] Processing record 194
# [1734947095.21] Processing record 195
# [1734947095.71] Processing record 196
# [1734947096.22] Processing record 197
# [1734947096.72] Processing record 198
# [1734947097.23] Processing record 199
# [1734947097.73] Processing record 200
# [1734947098.24] Processing record 201
# [1734947098.74] Processing record 202
# [1734947099.25] Processing record 203
# [1734947099.75] Processing record 204
# [1734947100.26] Processing record 205
# [1734947100.77] Processing record 206
# [1734947101.27] Processing record 207
# [1734947101.78] Processing record 208
# [1734947102.28] Processing record 209
# [1734947102.78] Processing record 210
# [1734947103.29] Processing record 211
# [1734947103.79] Processing record 212
# [1734947104.3] Processing record 213
# [1734947104.8] Processing record 214
# [1734947105.31] Processing record 215
# [1734947105.82] Processing record 216
# [1734947106.32] Processing record 217
# [1734947106.83] Processing record 218
# [1734947107.33] Processing record 219
# [1734947107.84] Processing record 220
# [1734947108.34] Processing record 221
# [1734947108.84] Processing record 222
# [1734947109.35] Processing record 223
# [1734947109.86] Processing record 224
# [1734947110.36] Processing record 225
# [1734947110.87] Processing record 226
# [1734947111.37] Processing record 227
# [1734947111.88] Processing record 228
# [1734947112.38] Processing record 229
# [1734947112.89] Processing record 230
# [1734947113.39] Processing record 231
# [1734947113.9] Processing record 232
# [1734947114.4] Processing record 233
# [1734947114.91] Processing record 234
# [1734947115.41] Processing record 235
# [1734947115.92] Processing record 236
# [1734947116.42] Processing record 237
# [1734947116.93] Processing record 238
# [1734947117.43] Processing record 239
# [1734947117.94] Processing record 240
# [1734947118.44] Processing record 241
# [1734947118.95] Processing record 242
# [1734947119.45] Processing record 243
# [1734947119.96] Processing record 244
# [1734947120.46] Processing record 245
# [1734947120.97] Processing record 246
# [1734947121.47] Processing record 247
# [1734947121.98] Processing record 248
# [1734947122.49] Processing record 249
# [1734947123.32] Peak memory usage: 89600875 bytes
# [1734947123.32] --- 139.51864576339722 seconds ---

# %%
# good practing routing to read node
driver.execute_query("MATCH (p:Person) RETURN p", routing_="r")
session.execute_read(lambda tx: tx.run("MATCH (p:Person) RETURN p"))

# bad practice 
driver.execute_query("MATCH (p:Person) RETURN p")
# defaults to routing = writers
session.execute_write(lambda tx: tx.run("MATCH (p:Person) RETURN p"))
# don't ask to write on a read-only operation

# %%
# Create an index on Person.name
driver.execute_query("CREATE INDEX person_name FOR (n:Person) ON (n.name)")

# %% [markdown]
# profile queries to find areas to improve

# %%
_, summary, _ = driver.execute_query("PROFILE MATCH (p:PLAYER {name: $name}) RETURN p", name="Ezra")
print(summary.profile['args']['string-representation'])
# Out:
# Cypher 5
#
# Planner COST
#
# Runtime PIPELINED
#
# Runtime version 5.24
#
# Batch size 128
#
# +------------------+----+----------------+----------------+------+---------+----------------+------------------------+-----------+---------------------+
# | Operator         | Id | Details        | Estimated Rows | Rows | DB Hits | Memory (Bytes) | Page Cache Hits/Misses | Time (ms) | Pipeline            |
# +------------------+----+----------------+----------------+------+---------+----------------+------------------------+-----------+---------------------+
# | +ProduceResults  |  0 | p              |              1 |    2 |       6 |              0 |                        |           |                     |
# | |                +----+----------------+----------------+------+---------+----------------+                        |           |                     |
# | +Filter          |  1 | p.name = $name |              1 |    2 |       8 |                |                        |           |                     |
# | |                +----+----------------+----------------+------+---------+----------------+                        |           |                     |
# | +NodeByLabelScan |  2 | p:PLAYER       |             10 |    4 |       5 |            248 |                    2/0 |     3.363 | Fused in Pipeline 0 |
# +------------------+----+----------------+----------------+------+---------+----------------+------------------------+-----------+---------------------+
#
# Total database accesses: 19, total allocated memory: 312
# /var/folders/pq/j682cyjd7cb0xq6g_rj_397w0000gn/T/ipykernel_29955/1745637161.py:1: DeprecationWarning: Using a driver after it has been closed is deprecated. Future versions of the driver will raise an error.
#   _, summary, _ = driver.execute_query("PROFILE MATCH (p:PLAYER {name: $name}) RETURN p", name="Ezra")

# %% [markdown]
# BATCH DATA creatioong using WITH AND UNWIND clauses

# %%
numbers = [{"value": random()} for _ in range(10000)]
driver.execute_query("""
    WITH $numbers AS batch
    UNWIND batch AS node
    MERGE (n:Number)
    SET n.value = node.value
    """, numbers=numbers,
)

# bad pracitice
for _ in range(10000):
    driver.execute_query("MERGE (:Number {value: $value})", value=random())
