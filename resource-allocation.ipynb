# %% [markdown]
# # Lean Construction
# Lean construction will involve the assessment of each of the project's operations - the efficiency and <br>
# effectiveness of its various operations, the reason for retaining specific operations and manpower, <br>
# the efficiency of equipment and machinery in the operation, number of people involved in particular <br>
# operation and detailed analysis of costs associated with each activity including both productive and <br>
# non productive operations and taking appropriate steps to improve operations by eliminating unnecessary operations.

# %% [markdown]
# # Brain Storm
# <img src="./images/iron-triangle.png" alt="Description of Image" width="600" height="500">
#
# ## Jobs to be done
# - Reduce stress of running out of money
# - Reduce stress  of overspending on resources such as labour
# - Monitor progress
# - A view of how the project is burning cash (From progress reports and earned value analysis)
# - Avoid conflicts with contractor and sub-contractor on value of completed work
# - Give reliable information so that project manager can prioritize work. E.g., if money is running out build first floor to completion
# - Analysis for best practice to transfer to the next project.
#
# ## Price analysis for constructing a Wall panel per day.
# To achieve this scope of work.
#  1. I require these set of skills [Mason for brick wall, person to tie bars incase of an RC wall, plastering guy for brick walls]
#  2. To ensure maximum utilization of these skills I require equipment and material. No scenario a worker is waiting for material or equipment
#
# ### Labour
# There is standard output for each skill. Have a database for standards of labour output, geofenced cost and rate. <br>
# This standard output will be under discussion by project managers in forums. <br>
# Let them come up with best practices that best suites them
#
# | Skill            | Standard Output                      | Cost (geofenced pricing) | Rate                    | Activity/Task                       |
# |------------------|--------------------------------------|--------------------------|-------------------------|-------------------------------------|
# | Mason            | Lays 150 bricks per day              | 1800                     |per 150 bricks(per day)  | Lay Bricks                          |
# | Plastering guy   | place 8 m^2 of concrete per day      | 2500                     |per 8 m^2 (per day)      | Plastering walls                    |
# | Man of Steel     | Ties 500 Kgs of steel per day        | 1800                     |per 500 Kgs (per day)    | Tie Steel Bars                      |
# | Concrete placer  | place 10 m^3 of concrete per day     | 1800                     |per 10 m^3 (per day)     | Place and Compact concrete          |
#
# NOTE: Starndard Output can vary from region to region.
#
# ### Accompanying labour
# Given in standards. Ideally One accompanying labour per skilled worker
# | Skill            | Accompnying labour                            | Cost (geofenced pricing) | Rate                    | Activity/Task                       |
# |------------------|-----------------------------------------------|--------------------------|-------------------------|-------------------------------------|
# | Mason            | 1 per mason                                   | 800                      |per 150 bricks(per day)  | Lay Bricks                          |
# | Plastering guy   | 1 per plastering guy                          | 800                      |per 8 m^2 (per day)      | Plastering walls                    |
#
# ### Material
# Should come from the scope of work start from the material to be consumed for the entire scope. <br>
# Then given the standards of output per labour and time constraints you can get the number of skilled labour to assign.
#
# Define scope of a brick wall panel of area length = 20m height=3m. <br>
# we want the actual product not the result. The product name is used to create orders on Jumba Ecosystem. <br>
# For example in construction they'll use Motor or Concrete but Jumba wants cement, sand, crushed stone and cement additivies. Solution; <br>
# Using the motor or concrete mix ratio calculate quantity of its components.
#
# | Raw Material                | details                       | Total Quantity (take advantage of bulk discount)                          | Unit of measure |Unit cost(geofenced pricing) |
# |-----------------------------|-------------------------------|---------------------------------------------------------------------------|-----------------|-----------------------------|
# | Bricks                      | 9 inches                      | 20000 blocks + 5% for wastage and breaking                                |per tone         |12,000                       |
# | Motar(cement, Sand, Water)  | Mix ratio(4:2:1 else standard)| M^3 needs a standard depending on bricks to be layed(best practice forums)|per m^3          |                             |
# | Motar Cement                | 32.5N                         | ratio x quantity of motor                                                 |per bag          |800                          |
# | Motar  Sand                 | River sand                    | ratio x quantity of motor                                                 |per tone         |6,000                        |
# | Motar Water                 | Fresh water                   | ratio x quantity of motor                                                 |per m^3          |3,000                        |
# | Motar Additives(water proof)| Water proof                   | ratio x quantity of motor                                                 |per kg           |300                          |
#
# Feature Request:
# - A forum where project managers suggest standards for labour output in terms of material consumption per labour etc. Make them feel they are part of a product.
#
# 1 mason 20000/150 = 134 days <br/>
# Time constraints requires wall in 10 days therefore activity requires:
# - 13 masons
# - 13 accompanying labour
#
# Feature Request:
# - Track labour on site, what activity they are assigned to. Keep a history of this. It is required to make payments.
#
# So you have the standard output for each skill required and the scope in this case wall panel. We calculate the duration <br>
# of each activity also lead and lag time if required (for this case we have only one activity construct wall panel). <br>
# Duration of each activity in the network diagram will give;
# - Project Duration
# - Precedence of each activity
# - Slack for each activity
# - Critical activities (cannot be delayed)
#
# ### Tools and Equipments
# We have two types of equipments; Have a geofenced pricing of this line of products.
# - Fixed Cost i.e., purchased cost is incurred once. Have a fixed cost price analysis and variable cost analysis
# - Variable Cost i.e., from leasing and renting. Cost is incurred at specified rates
#
# Equipments required: Trowel, brick hammer, spirit level, plumb bob, measuring tape, wheelbaroow, bucket, hawk board,
# Safety gear: gloves, googles, hard hat, boots
# Workspace setup: Scaffolding, storage area
#
# All of the above are fixed cost of the activity. put it at = 3500 /=
#
# Now we have the skill required and the duration to perform each activity. To make sure that the scope is completed at agreed duration.<br>
# We have to ensure maximum utilization of these skills. For maximum utilization of these skills it will require materials, equipment and accompanying<br>
# labour to be available when required.
#
# ### Rate of burning cash per day, can be converted to any unit of time greater than a day.
# The contractor always logs the tiniest details. (show the example)
# - 13 masons allocated at the rate of 23400 per day
# - 13 accompanying labour allocated at the rate of 10400 per day
# - 1950 bricks per day allocated at the rate of if 1 brick was bought at 15bob therefore = 30713 per day
# For motor consumed per day price analysis for components making up the motor.
# - 10 bags of cement allocated at the rate of 8000 per day
# - X vol of sand allocated at the rate of 3000 per day
# - X vol of water =  800 per day
# - X kg of water proofing - 1200 per day
#
# Total cost per day = 77,513 for activity constructing wall.
#
# Now automate this price analysis which will give budgeted cost <br>
# From the automated field report will give actual cost incurred<br>
# Having the progress of each acvitity, actual cost incurred and budgeted cost we can perform earned value analysis.<br>
# The earned value analysis will tell whether the project is within schedule and within budget <br>
# The information from the network diagram will be used to assess the project operations. (Strive for lean construction)
#
# ## Design Overview From a users perspective
# Presented with a network diagram when i click a node i should see the price analysis, rate of burning mone for that activity, progress, <br>

# %% [markdown]
# ### Labour
# Developers account will have this resources and the cost

# %%
from enum import Enum
from typing import Optional, List
from pydantic import BaseModel, Field

class SkillEnum(str, Enum):
    plumbing = "plumbing"
    masonry = "masonry"
    carpentry = "carpentry"  
    electrical = "electrical"
    mechanical = "mechanical"
    painting = "painting"
    welding = "welding"

class RateEnum(str, Enum):
    perHour = "per-hour"
    perDay = "per-day"
    perTask = "per-task" 

class GroupEnum(str, Enum):
    admin = "admin"
    supervisor = "supervisor"
    worker = "worker"

# Job class to describe roles
class Job(BaseModel):
    title: str = Field(..., description="Job title, e.g., construction manager, resident engineer")
    description: Optional[str] = Field(None, description="Optional description of the job role")

# Skill class to define a skill and its associated rate
class Skill(BaseModel):
    type: SkillEnum = Field(..., description="Type of skill, e.g., plumbing, masonry")
    rate: RateEnum = Field(..., description="Rate type, e.g., per-hour, per-day")
    remuneration: float = Field(..., gt=0, description="Remuneration value must be greater than 0")

# Employee class for system authentication and user information
class Employee(BaseModel):
    name: str = Field(..., description="Full name of the employee")
    password: Optional[str] = Field(None, description="Optional password for system authentication")
    username: Optional[str] = Field(None, description="Optional unique username for the employee")
    group: Optional[GroupEnum] = Field(None, description="Employee group classification")
    job: Optional[Job] = Field(None, description="Job details for the employee")
    skills: Optional[List[Skill]] = Field(default_factory=list, description="List of skills possessed by the employee")

# EmployeeSkill class to link an employee to a skill
class EmployeeSkill(BaseModel):
    skill: Skill = Field(..., description="The skill the employee possesses")
    employee: Employee = Field(..., description="The employee associated with this skill")

# Labor class for representing available labor and their associated skill
class Labor(BaseModel):
    type: SkillEnum = Field(..., description="The type of labor skill")
    employee: Employee = Field(..., description="The employee performing this labor task")

# %% [markdown]
# ### Equipment
# Developers account will have these resource

# %%
from pydantic import BaseModel, Field
from enum import Enum

# Enum to represent equipment sourcing options
class EquipmentSourceEnum(str, Enum):
    purchase = "purchase"  # Buying the equipment outright
    leasing = "leasing"  # Leasing for a period, may include a purchase option 
    renting = "renting"  # Renting for temporary use

# Model to represent equipment details
class Equipment(BaseModel):
    name: str = Field(..., description="The name of the equipment")
    description: str = Field(..., description="A detailed description of the equipment")
    source: EquipmentSourceEnum = Field(..., description="The sourcing method for the equipment")
    rate: RateEnum = Field(..., description="The rate type for the equipment (per hour or per day)")
    cost: float = Field(..., gt=0, description="The base cost of the equipment usage")
    transport_cost: float = Field(0, ge=0, description="The cost of transporting the equipment, default is 0")

# %% [markdown]
# ### Material
# Developer will have an inventory management system to keep track of materials on site (this inventory can be used by hardwares as well). <br>
# If inventory runs low Jumba ecosystem creates an order. <br>
# User only has to confirm the order and add delivery details when the product is required. <br>
# Have a 3 days grace period after confirming order for Jumba to fullfill orders <br>
